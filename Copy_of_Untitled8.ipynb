# %% [markdown]
# <a href="https://colab.research.google.com/github/mading225/dsc-git-intro/blob/master/Copy_of_Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the data
import json
with open('MOCK_DATA.json') as f:
  data = json.load(f)

data
# Out:
# [{'id': 1,
#   'first_name': 'Rutherford',
#   'last_name': 'Bruce',
#   'email': 'rbruce0@g.co',
#   'gender': 'Male',
#   'car year': 2012,
#   'date': '4/2/2025',
#   'car': 'Infiniti'},
#  {'id': 2,
#   'first_name': 'Benedicta',
#   'last_name': 'Todarini',
#   'email': 'btodarini1@php.net',
#   'gender': 'Female',
#   'car year': 1993,
#   'date': '10/28/2024',
#   'car': 'Chevrolet'},
#  {'id': 3,
#   'first_name': 'Kylila',
#   'last_name': 'Sant',
#   'email': 'ksant2@hatena.ne.jp',
#   'gender': 'Female',
#   'car year': 1997,
#   'date': '7/31/2024',
#   'car': 'Buick'},
#  {'id': 4,
#   'first_name': 'Aymer',
#   'last_name': 'Stallen',
#   'email': 'astallen3@blinklist.com',
#   'gender': 'Male',
#   'car year': 2010,
#   'date': '4/28/2025',
#   'car': 'Nissan'},
#  {'id': 5,
#   'first_name': 'Minny',
#   'last_name': 'Agate',
#   'email': 'magate4@hostgator.com',
#   'gender': 'Female',
#   'car year': 2001,
#   'date': '3/26/2025',
#   'car': 'Toyota'},
#  {'id': 6,
# ...

# %%
#next step
import pandas as pd
mock_data = pd.DataFrame(data)
mock_data
# Out:
#        id  first_name last_name                    email       gender  \
# 0       1  Rutherford     Bruce             rbruce0@g.co         Male
# 1       2   Benedicta  Todarini       btodarini1@php.net       Female
# 2       3      Kylila      Sant      ksant2@hatena.ne.jp       Female
# 3       4       Aymer   Stallen  astallen3@blinklist.com         Male
# 4       5       Minny     Agate    magate4@hostgator.com       Female
# ..    ...         ...       ...                      ...          ...
# 995   996       Nance   Cicullo      ncicullorn@furl.net     Bigender
# 996   997      Gorden      Pell   gpellro@macromedia.com         Male
# 997   998      Vivian     Busch          vbuschrp@hp.com  Genderqueer
# 998   999      Lezley    Duffer  ldufferrq@123-reg.co.uk         Male
# 999  1000   Madelaine  Stadding   mstaddingrr@taobao.com      Agender
#
#      car year        date         car
# 0        2012    4/2/2025    Infiniti
# 1        1993  10/28/2024   Chevrolet
# ...

# %%
#next step
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   car year    1000 non-null   int64
#  6   date        960 non-null    object
#  7   car         968 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 62.6+ KB

# %%
mock_data.head()
# Out:
#    id  first_name last_name                    email  gender  car year  \
# 0   1  Rutherford     Bruce             rbruce0@g.co    Male      2012
# 1   2   Benedicta  Todarini       btodarini1@php.net  Female      1993
# 2   3      Kylila      Sant      ksant2@hatena.ne.jp  Female      1997
# 3   4       Aymer   Stallen  astallen3@blinklist.com    Male      2010
# 4   5       Minny     Agate    magate4@hostgator.com  Female      2001
#
#          date        car
# 0    4/2/2025   Infiniti
# 1  10/28/2024  Chevrolet
# 2   7/31/2024      Buick
# 3   4/28/2025     Nissan
# 4   3/26/2025     Toyota

# %%
#cleaning the data
mock_data.isnull().sum()
# Out:
# id             0
# first_name     0
# last_name      0
# email          0
# gender         0
# car year       0
# date          40
# car           32
# dtype: int64

# %%
#checking the shape of our dataframe
mock_data.shape
# Out:
# (1000, 8)

# %%
# next step
for index, row in mock_data[['first_name','last_name']].iterrows():
  print(row['first_name'], row['last_name'])
# Out:
# Rutherford Bruce
# Benedicta Todarini
# Kylila Sant
# Aymer Stallen
# Minny Agate
# Scot Bruntje
# Jarvis Owttrim
# Gaby Marcham
# Wilie Hun
# Moselle Hardy
# Theressa Meenehan
# Stephannie Foulsham
# Ricky Faircliffe
# Gaylene Piff
# Dar Cutten
# Anneliese Bourges
# Kimmy Atcock
# Faunie Dukelow
# Winnie Dallmann
# Iver Hardwell
# Enos Lockie
# Bryce Woodroff
# Shae MacCallester
# Myrah Tothacot
# Cora Lasseter
# Bordy Willerson
# Mattheus Gillingwater
# Corinne Duigenan
# Christine Haslum
# Cornall Sallery
# Arley Dayer
# Elga Rubega
# Bamby Simonel
# Avigdor Klewer
# Aubrey Bartrum
# Joellen Hetterich
# Mada Trigwell
# Martie Watkiss
# Russ Fitzjohn
# Jenny Cree
# Florie Jovic
# Steffie Showers
# Nathan Pessolt
# Olympie Drinkhill
# Libbey Jex
# Cob Barby
# Osbourn Lutwyche
# Immanuel Cuniam
# Thedric Braunton
# Cole Pigdon
# Francoise Oneil
# Boone Cooling
# Brenden Rockwill
# Amelita Dundon
# Culley Hathwood
# Elyn Blaxill
# Louisette Patry
# Bren Wilstead
# Allix Edsall
# ...

# %%
for i in mock_data['date']:
  print(i)
# Out:
# 4/2/2025
# 10/28/2024
# 7/31/2024
# 4/28/2025
# 3/26/2025
# 6/6/2025
# 7/27/2024
# 3/21/2025
# 8/15/2024
# 3/5/2025
# 5/13/2025
# 1/24/2025
# 2/20/2025
# 2/2/2025
# 4/2/2025
# 5/17/2025
# 6/6/2025
# 4/21/2025
# 11/6/2024
# 11/15/2024
# 4/18/2025
# 2/3/2025
# 11/22/2024
# 9/29/2024
# 2/21/2025
# 6/5/2025
# 4/14/2025
# 11/19/2024
# 12/28/2024
# 5/4/2025
# 11/30/2024
# 10/16/2024
# 12/2/2024
# 2/15/2025
# 8/18/2024
# 8/17/2024
# 10/20/2024
# 5/13/2025
# 6/13/2025
# 10/22/2024
# 3/1/2025
# 6/4/2025
# 8/18/2024
# 10/22/2024
# 10/18/2024
# 1/8/2025
# 2/16/2025
# 3/21/2025
# 4/5/2025
# 11/7/2024
# 9/30/2024
# 3/15/2025
# 11/21/2024
# 6/20/2025
# 2/18/2025
# 12/2/2024
# 7/28/2024
# 1/21/2025
# 7/10/2025
# 4/11/2025
# 6/16/2025
# 3/22/2025
# 8/29/2024
# 6/20/2025
# 6/17/2025
# 8/2/2024
# 12/13/2024
# 1/20/2025
# 7/11/2025
# 3/29/2025
# 5/13/2025
# 5/12/2025
# 1/4/2025
# 3/2/2025
# 7/6/2025
# 10/10/2024
# 8/18/2024
# 8/18/2024
# 3/20/2025
# 8/4/2024
# 11/15/2024
# 7/7/2025
# 5/27/2025
# ...

# %%
import pandas as pd
mock_data = pd.DataFrame(data)
mock_data['date'] = mock_data['date'].fillna("16/07/2025")
print(mock_data)
# Out:
#        id  first_name last_name                    email       gender  \
# 0       1  Rutherford     Bruce             rbruce0@g.co         Male
# 1       2   Benedicta  Todarini       btodarini1@php.net       Female
# 2       3      Kylila      Sant      ksant2@hatena.ne.jp       Female
# 3       4       Aymer   Stallen  astallen3@blinklist.com         Male
# 4       5       Minny     Agate    magate4@hostgator.com       Female
# ..    ...         ...       ...                      ...          ...
# 995   996       Nance   Cicullo      ncicullorn@furl.net     Bigender
# 996   997      Gorden      Pell   gpellro@macromedia.com         Male
# 997   998      Vivian     Busch          vbuschrp@hp.com  Genderqueer
# 998   999      Lezley    Duffer  ldufferrq@123-reg.co.uk         Male
# 999  1000   Madelaine  Stadding   mstaddingrr@taobao.com      Agender
#
#      car year        date         car
# 0        2012    4/2/2025    Infiniti
# 1        1993  10/28/2024   Chevrolet
# ...

# %%
mock_data.isnull().sum()
# Out:
# id             0
# first_name     0
# last_name      0
# email          0
# gender         0
# car year       0
# date           0
# car           32
# dtype: int64

# %%
for i in mock_data['car']:
  print(i)
# Out:
# Infiniti
# Chevrolet
# Buick
# Nissan
# Toyota
# Hyundai
# Toyota
# Ford
# Porsche
# Saab
# Chevrolet
# Lexus
# Hummer
# Mercedes-Benz
# Buick
# Kia
# Honda
# Mercedes-Benz
# Buick
# Pontiac
# Dodge
# Lincoln
# Ford
# Kia
# Honda
# None
# Volvo
# Saab
# Mercedes-Benz
# Chrysler
# Volkswagen
# Mercury
# Infiniti
# Chevrolet
# Mazda
# Volkswagen
# Ford
# Chrysler
# Ford
# Subaru
# Chevrolet
# Lexus
# Acura
# Volkswagen
# Mitsubishi
# Cadillac
# GMC
# Acura
# Ford
# GMC
# Lincoln
# None
# Volkswagen
# Ford
# Ford
# Mitsubishi
# Dodge
# GMC
# Volvo
# Chrysler
# Dodge
# Hyundai
# Suzuki
# Volvo
# Mercedes-Benz
# Lincoln
# Land Rover
# Ford
# GMC
# Volkswagen
# Kia
# Chevrolet
# Chevrolet
# GMC
# BMW
# Lexus
# Chevrolet
# Lincoln
# Lincoln
# Chevrolet
# Mazda
# Audi
# Toyota
# Mazda
# Ford
# Mazda
# Lexus
# Hyundai
# Eagle
# None
# Dodge
# Cadillac
# Maybach
# Aston Martin
# Subaru
# Ford
# Mercedes-Benz
# Mercury
# Mazda
# Buick
# BMW
# BMW
# Ferrari
# GMC
# GMC
# Kia
# Ford
# Dodge
# ...

# %%
mock_data = pd.DataFrame(data)
mock_data['car'] = mock_data['car'].fillna("G.wagon")
print(mock_data)
# Out:
#        id  first_name last_name                    email       gender  \
# 0       1  Rutherford     Bruce             rbruce0@g.co         Male
# 1       2   Benedicta  Todarini       btodarini1@php.net       Female
# 2       3      Kylila      Sant      ksant2@hatena.ne.jp       Female
# 3       4       Aymer   Stallen  astallen3@blinklist.com         Male
# 4       5       Minny     Agate    magate4@hostgator.com       Female
# ..    ...         ...       ...                      ...          ...
# 995   996       Nance   Cicullo      ncicullorn@furl.net     Bigender
# 996   997      Gorden      Pell   gpellro@macromedia.com         Male
# 997   998      Vivian     Busch          vbuschrp@hp.com  Genderqueer
# 998   999      Lezley    Duffer  ldufferrq@123-reg.co.uk         Male
# 999  1000   Madelaine  Stadding   mstaddingrr@taobao.com      Agender
#
#      car year        date         car
# 0        2012    4/2/2025    Infiniti
# 1        1993  10/28/2024   Chevrolet
# ...

# %%
mock_data.isnull().sum()
# Out:
# id             0
# first_name     0
# last_name      0
# email          0
# gender         0
# car year       0
# date          40
# car            0
# dtype: int64

# %%
for i in mock_data['car']:
  print(i)
# Out:
# Infiniti
# Chevrolet
# Buick
# Nissan
# Toyota
# Hyundai
# Toyota
# Ford
# Porsche
# Saab
# Chevrolet
# Lexus
# Hummer
# Mercedes-Benz
# Buick
# Kia
# Honda
# Mercedes-Benz
# Buick
# Pontiac
# Dodge
# Lincoln
# Ford
# Kia
# Honda
# G.wagon
# Volvo
# Saab
# Mercedes-Benz
# Chrysler
# Volkswagen
# Mercury
# Infiniti
# Chevrolet
# Mazda
# Volkswagen
# Ford
# Chrysler
# Ford
# Subaru
# Chevrolet
# Lexus
# Acura
# Volkswagen
# Mitsubishi
# Cadillac
# GMC
# Acura
# Ford
# GMC
# Lincoln
# G.wagon
# Volkswagen
# Ford
# Ford
# Mitsubishi
# Dodge
# GMC
# Volvo
# Chrysler
# Dodge
# Hyundai
# Suzuki
# Volvo
# Mercedes-Benz
# Lincoln
# Land Rover
# Ford
# GMC
# Volkswagen
# Kia
# Chevrolet
# Chevrolet
# GMC
# BMW
# Lexus
# Chevrolet
# Lincoln
# Lincoln
# Chevrolet
# Mazda
# Audi
# Toyota
# Mazda
# Ford
# Mazda
# Lexus
# Hyundai
# Eagle
# G.wagon
# Dodge
# Cadillac
# Maybach
# Aston Martin
# Subaru
# Ford
# Mercedes-Benz
# Mercury
# Mazda
# Buick
# BMW
# BMW
# Ferrari
# GMC
# GMC
# Kia
# Ford
# ...

# %%
mock_data.isna().sum()
# Out:
# id             0
# first_name     0
# last_name      0
# email          0
# gender         0
# car year       0
# date          40
# car            0
# dtype: int64

# %%
for i in mock_data['date']:
  print(i)
# Out:
# 4/2/2025
# 10/28/2024
# 7/31/2024
# 4/28/2025
# 3/26/2025
# 6/6/2025
# 7/27/2024
# 3/21/2025
# 8/15/2024
# 3/5/2025
# 5/13/2025
# 1/24/2025
# 2/20/2025
# 2/2/2025
# 4/2/2025
# 5/17/2025
# 6/6/2025
# 4/21/2025
# 11/6/2024
# 11/15/2024
# 4/18/2025
# 2/3/2025
# 11/22/2024
# 9/29/2024
# 2/21/2025
# 6/5/2025
# 4/14/2025
# 11/19/2024
# 12/28/2024
# 5/4/2025
# 11/30/2024
# 10/16/2024
# 12/2/2024
# 2/15/2025
# 8/18/2024
# 8/17/2024
# 10/20/2024
# 5/13/2025
# 6/13/2025
# 10/22/2024
# 3/1/2025
# 6/4/2025
# 8/18/2024
# 10/22/2024
# 10/18/2024
# 1/8/2025
# 2/16/2025
# 3/21/2025
# 4/5/2025
# 11/7/2024
# 9/30/2024
# 3/15/2025
# 11/21/2024
# 6/20/2025
# 2/18/2025
# 12/2/2024
# 7/28/2024
# 1/21/2025
# 7/10/2025
# 4/11/2025
# 6/16/2025
# 3/22/2025
# 8/29/2024
# 6/20/2025
# 6/17/2025
# 8/2/2024
# 12/13/2024
# 1/20/2025
# 7/11/2025
# 3/29/2025
# 5/13/2025
# 5/12/2025
# 1/4/2025
# 3/2/2025
# 7/6/2025
# 10/10/2024
# 8/18/2024
# 8/18/2024
# 3/20/2025
# 8/4/2024
# 11/15/2024
# 7/7/2025
# 5/27/2025
# ...

# %%
mock_data = pd.DataFrame(data)
mock_data['date'] = mock_data['date'].fillna("16/07/2025")
mock_data = pd.DataFrame(data)
mock_data['car'] = mock_data['car'].fillna("G.wagon")
print(mock_data)
# Out:
#        id  first_name last_name                    email       gender  \
# 0       1  Rutherford     Bruce             rbruce0@g.co         Male
# 1       2   Benedicta  Todarini       btodarini1@php.net       Female
# 2       3      Kylila      Sant      ksant2@hatena.ne.jp       Female
# 3       4       Aymer   Stallen  astallen3@blinklist.com         Male
# 4       5       Minny     Agate    magate4@hostgator.com       Female
# ..    ...         ...       ...                      ...          ...
# 995   996       Nance   Cicullo      ncicullorn@furl.net     Bigender
# 996   997      Gorden      Pell   gpellro@macromedia.com         Male
# 997   998      Vivian     Busch          vbuschrp@hp.com  Genderqueer
# 998   999      Lezley    Duffer  ldufferrq@123-reg.co.uk         Male
# 999  1000   Madelaine  Stadding   mstaddingrr@taobao.com      Agender
#
#      car year        date         car
# 0        2012    4/2/2025    Infiniti
# 1        1993  10/28/2024   Chevrolet
# ...

# %%
mock_data.dropna(inplace=True) # dropna removes the rows with missing values__the inplace modifies the data frame directly

mock_data.isna().sum()
# Out:
# id            0
# first_name    0
# last_name     0
# email         0
# gender        0
# car year      0
# date          0
# car           0
# dtype: int64
