# %% [markdown]
# <a href="https://colab.research.google.com/github/mading225/dsc-git-intro/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('bom.movie_gross.csv.gz')

df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df.tail()
# Out:
#                             title      studio  domestic_gross foreign_gross  \
# 3382                    The Quake       Magn.          6200.0           NaN
# 3383  Edward II (2018 re-release)          FM          4800.0           NaN
# 3384                     El Pacto        Sony          2500.0           NaN
# 3385                     The Swan  Synergetic          2400.0           NaN
# 3386            An Actor Prepares       Grav.          1700.0           NaN
#
#       year
# 3382  2018
# 3383  2018
# 3384  2018
# 3385  2018
# 3386  2018

# %%
df.shape
# Out:
# (3387, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
df.isna().mean()
# Out:
# title             0.000000
# studio            0.001476
# domestic_gross    0.008267
# foreign_gross     0.398583
# year              0.000000
# dtype: float64

# %%
#Lets get the rows which have missing data
df[df.isna().any(axis=1)]
# Out:
#                                        title      studio  domestic_gross  \
# 210            Outside the Law (Hors-la-loi)         NaN         96900.0
# 222                                  Flipped          WB       1800000.0
# 230               It's a Wonderful Afterlife         UTV             NaN
# 254   The Polar Express (IMAX re-issue 2010)          WB        673000.0
# 267                           Tiny Furniture         IFC        392000.0
# ...                                      ...         ...             ...
# 3382                               The Quake       Magn.          6200.0
# 3383             Edward II (2018 re-release)          FM          4800.0
# 3384                                El Pacto        Sony          2500.0
# 3385                                The Swan  Synergetic          2400.0
# 3386                       An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 210        3300000  2010
# 222            NaN  2010
# ...

# %%
'''df.dropna(axis=0,how='all',inplace = True)'''
df # i don't think here it achieved wat i wanted
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    3387
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for x in df.columns:
  print(x, ":",df[x].unique(),'\n')
# Out:
# title : ['Toy Story 3' 'Alice in Wonderland (2010)'
#  'Harry Potter and the Deathly Hallows Part 1' ... 'El Pacto' 'The Swan'
#  'An Actor Prepares']
#
# studio : ['BV' 'WB' 'P/DW' 'Sum.' 'Par.' 'Uni.' 'Fox' 'Wein.' 'Sony' 'FoxS' 'SGem'
#  'WB (NL)' 'LGF' 'MBox' 'CL' 'W/Dim.' 'CBS' 'Focus' 'MGM' 'Over.' 'Mira.'
#  'IFC' 'CJ' 'NM' 'SPC' 'ParV' 'Gold.' 'JS' 'RAtt.' 'Magn.' 'Free' '3D'
#  'UTV' 'Rela.' 'Zeit.' 'Anch.' 'PDA' 'Lorb.' 'App.' 'Drft.' 'Osci.' 'IW'
#  'Rog.' nan 'Eros' 'Relbig.' 'Viv.' 'Hann.' 'Strand' 'NGE' 'Scre.' 'Kino'
#  'Abr.' 'CZ' 'ATO' 'First' 'GK' 'FInd.' 'NFC' 'TFC' 'Pala.' 'Imag.' 'NAV'
#  'Arth.' 'CLS' 'Mont.' 'Olive' 'CGld' 'FOAK' 'IVP' 'Yash' 'ICir' 'FM'
#  'Vita.' 'WOW' 'Truly' 'Indic.' 'FD' 'Vari.' 'TriS' 'ORF' 'IM' 'Elev.'
#  'Cohen' 'NeoC' 'Jan.' 'MNE' 'Trib.' 'Rocket' 'OMNI/FSR' 'KKM' 'Argo.'
#  'SMod' 'Libre' 'FRun' 'WHE' 'P4' 'KC' 'SD' 'AM' 'MPFT' 'Icar.' 'AGF'
#  'A23' 'Da.' 'NYer' 'Rialto' 'DF' 'KL' 'ALP' 'LG/S' 'WGUSA' 'MPI' 'RTWC'
# ...

# %%
df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
df['title'].describe()
# Out:
# count          3387
# unique         3386
# top       Bluebeard
# freq              2
# Name: title, dtype: object

# %%
df['title'] = df['title'].str.capitalize()
df['studio'] = df['studio'].str.capitalize()
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy story 3          Bv     415000000.0
# 1                      Alice in wonderland (2010)          Bv     334200000.0
# 2     Harry potter and the deathly hallows part 1          Wb     296000000.0
# 3                                       Inception          Wb     292600000.0
# 4                             Shrek forever after        P/dw     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The quake       Magn.          6200.0
# 3383                  Edward ii (2018 re-release)          Fm          4800.0
# 3384                                     El pacto        Sony          2500.0
# 3385                                     The swan  Synergetic          2400.0
# 3386                            An actor prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df.nunique()
# Out:
# title             3386
# studio             257
# domestic_gross    1797
# foreign_gross     1204
# year                 9
# dtype: int64

# %%
sns.boxplot(data=df)
plt.title('Checking for outliers')
# Out:
# Text(0.5, 1.0, 'Checking for outliers')

# %%
plt.scatter(df['year'], df['domestic_gross'])
plt.xlabel('year')
plt.ylabel('domestic_gross')
plt.title('Scatter plot')
plt.show()

# %%
plt.scatter(df['foreign_gross'], df['domestic_gross'])
plt.xlabel('year')
plt.ylabel('domestic_gross')
plt.title('Scatter plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3077822690.py in <cell line: 0>()
# ----> 1 plt.scatter(df['foreign_gross'], df['domestic_gross'])
#       2 plt.xlabel('year')
#       3 plt.ylabel('domestic_gross')
#       4 plt.title('Scatter plot')
#       5 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
# ...

# %%
plt.scatterplot(df['domestic_gross'],df['foreign_gross'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2409384056.py in <cell line: 0>()
# ----> 1 plt.scatterplot(df['domestic_gross'],df['foreign_gross'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scatterplot'

# %%
df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
# matplotlib
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.mean('domestic_gross')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     575         try:
# --> 576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
#
# KeyError: 'domestic_gross'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-882835316.py in <cell line: 0>()
# ----> 1 df.mean('domestic_gross')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
# ...

# %%
'''df.median'''

# %%
'''df.mode'''

# %%
'''df.skew'''
# Out:
# 'df.skew'

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'domestic_gross'}>,
#         <Axes: title={'center': 'year'}>]], dtype=object)

# %%
'''df.kurt()'''

# %%
plt.bar
# Out:
# <BarContainer object of 1 artists>

# %%
df['year'].plot(kind='hist',bins=9,density = True, edgecolor='black')
plt.title('Years Of Movie Release')
plt.show()

# %%
df['domestic_gross'].plot(kind='hist',bins=9,density = True, edgecolor='black')
plt.title('Years Of Movie Release')
# Out:
# Text(0.5, 1.0, 'Years Of Movie Release')

# %%
studio = df['studio'].value_counts()
studio
# Out:
# studio
# IFC           166
# Uni.          147
# WB            140
# Fox           136
# Magn.         136
#              ...
# Crimson         1
# EF              1
# Arrow           1
# Hiber           1
# Synergetic      1
# Name: count, Length: 257, dtype: int64

# %%
studio.plot(kind='bar')
# Out:
# <Axes: xlabel='studio'>

# %%
df['studio'].value_counts().head(10)
# Out:
# studio
# IFC      166
# Uni.     147
# WB       140
# Fox      136
# Magn.    136
# SPC      123
# Sony     110
# BV       106
# LGF      103
# Par.     101
# Name: count, dtype: int64

# %%
sns.histplot(df['year'],bins =9)
plt.title('Year histogram')
# Out:
# Text(0.5, 1.0, 'Year histogram')

# %%
df['domestic_gross'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['year'].value_counts().plot(kind='pie',autopct = '%1.1f%%')
plt.title('foreign_gross')
# Out:
# Text(0.5, 1.0, 'foreign_gross')

# %%
sns.lineplot(data=df,x=df['year'],y=df['domestic_gross'])
# Out:
# <Axes: xlabel='year', ylabel='domestic_gross'>

# %%
df.corr(numeric_only=True)
# Out:
#                 domestic_gross      year
# domestic_gross        1.000000  0.018708
# year                  0.018708  1.000000

# %%
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='viridis')

heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':2}, pad=2);

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df.corr(numeric_only=True)[['domestic_gross']].sort_values(by='domestic_gross', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Domestic Gross', fontdict={'fontsize':18}, pad=16);

# %%
sns.lineplot(data=df,x=df['year'],y=df['foreign_gross'])
plt.title('Foreign Gross Over Time')
# Out:
# Text(0.5, 1.0, 'Foreign Gross Over Time')

# %%
df[['domestic_gross', 'studio', 'title', 'year', 'foreign_gross']].boxplot()
plt.figure(figsize=(10,8))

# %%
df['foreign_gross'] = pd.to_numeric(df['foreign_gross'], errors='coerce')

plt.scatter(df['foreign_gross'], df['domestic_gross'])
plt.xlabel('Foreign Gross')
plt.ylabel('Domestic Gross')
plt.title('Foreign Gross vs. Domestic Gross')
plt.show()

# %%
studio.head(10).plot(kind='bar')
plt.title('Top 10 Studios by Number of Movies Released')
plt.ylabel('Number of Movies')
plt.xlabel('Studio')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
studio.head(10).plot(kind='bar')
plt.title('Top 10 Studios')
plt.xlabel('Studio')
plt.ylabe
# Out:
# Text(0.5, 0, 'Studio')
